# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
df = pd.read_csv("covid19_deaths_dataset.csv")
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
df.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# #### Removing duplicates and null collumns

# %%
df.drop_duplicates()
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
df.dropna()
# Out:
#                        Province/State  Country/Region      Lat      Long  \
# 8        Australian Capital Territory       Australia -35.4735  149.0124
# 9                     New South Wales       Australia -33.8688  151.2093
# 10                 Northern Territory       Australia -12.4634  130.8456
# 11                         Queensland       Australia -28.0167  153.4000
# 12                    South Australia       Australia -34.9285  138.6007
# ..                                ...             ...      ...       ...
# 250            British Virgin Islands  United Kingdom  18.4207  -64.6400
# 251          Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 256  Bonaire, Sint Eustatius and Saba     Netherlands  12.1784  -68.2385
# 258       Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 259         Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# ...

# %%
df.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
df.drop(columns = ['Lat', 'Long'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
df_country = df.groupby(by=['Country/Region']).sum(numeric_only=True)

# %%
df_country.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
df_country.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
df_country.loc['China'].plot()
df_country.loc['Russia'].plot()
df_country.loc['Japan'].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
df_country.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
### Ploting only the first three days data

# %%
df_country.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
df_country.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 3.2: find maxmimum dath rate for China

# %%
df_country.loc['China'].diff().max()
# Out:
# 1290.0

# %%
df_country.loc['Russia'].diff().max()
# Out:
# 105.0

# %%
df_country.loc['Japan'].diff().max()
# Out:
# 47.0

# %% [markdown]
# ### Task 3.3: find maximum death rate for all of the countries.

# %%
countries_list = list(df_country.index)
death_rate = []
for c in countries_list : 
    death_rate.append(df_country.loc[c].diff().max())
death_rate
# Out:
# [7.0,
#  4.0,
#  30.0,
#  4.0,
#  2.0,
#  1.0,
#  13.0,
#  3.0,
#  8.0,
#  30.0,
#  3.0,
#  3.0,
#  1.0,
#  15.0,
#  1.0,
#  5.0,
#  496.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  6.0,
#  1.0,
#  493.0,
#  1.0,
#  6.0,
#  4.0,
#  2.0,
#  1.0,
#  1.0,
#  0.0,
#  20.0,
#  251.0,
#  0.0,
#  3.0,
#  13.0,
#  1290.0,
#  26.0,
#  0.0,
#  3.0,
#  5.0,
#  1.0,
#  4.0,
#  8.0,
#  6.0,
#  2.0,
#  18.0,
#  22.0,
#  2.0,
#  1.0,
#  0.0,
#  38.0,
#  208.0,
#  22.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  1.0,
#  2.0,
#  0.0,
#  43.0,
#  1440.0,
#  1.0,
#  1.0,
#  1.0,
#  510.0,
#  5.0,
#  10.0,
#  0.0,
#  3.0,
#  2.0,
#  1.0,
#  2.0,
#  2.0,
#  0.0,
#  8.0,
#  23.0,
#  5.0,
#  75.0,
#  60.0,
#  158.0,
#  7.0,
#  220.0,
#  13.0,
#  919.0,
#  2.0,
#  47.0,
#  2.0,
#  5.0,
#  2.0,
#  11.0,
#  10.0,
#  4.0,
#  3.0,
#  0.0,
#  4.0,
#  2.0,
#  4.0,
#  1.0,
#  1.0,
#  6.0,
#  8.0,
#  2.0,
#  0.0,
#  1.0,
#  8.0,
#  1.0,
#  4.0,
#  1.0,
#  1.0,
#  2.0,
#  163.0,
#  10.0,
#  2.0,
#  0.0,
#  1.0,
#  12.0,
#  0.0,
# ...

# %%
df_country["max_death_rate"] = death_rate
df_country.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
df_mir = pd.DataFrame(df_country['max_death_rate'])
df_mir.head()
# Out:
#                 max_death_rate
# Country/Region
# Afghanistan                7.0
# Albania                    4.0
# Algeria                   30.0
# Andorra                    4.0
# Angola                     2.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
df_whr = pd.read_csv("worldwide_happiness_report.csv")

# %%
df_whr.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
colToDrop = ['Overall rank', 'Score', 'Generosity', 'Perceptions of corruption']
df_whr.drop(colToDrop, axis = 1, inplace = True)
df_whr.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %% [markdown]
# ### Change the index of the dataframe so it corresponds to the country or region

# %%
df_whr.set_index("Country or region", inplace = True)

# %%
df_whr.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
df_country.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
df_country.shape
# Out:
# (187, 101)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
df_whr.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
df_whr.shape
# Out:
# (156, 4)

# %% [markdown]
# ### Join the two tables

# %%
df_join = df_whr.join(df_mir, how="inner")
df_join.head()
# Out:
#              GDP per capita  Social support  Healthy life expectancy  \
# Finland               1.340           1.587                    0.986
# Denmark               1.383           1.573                    0.996
# Norway                1.488           1.582                    1.028
# Iceland               1.380           1.624                    1.026
# Netherlands           1.396           1.522                    0.999
#
#              Freedom to make life choices  max_death_rate
# Finland                             0.596            43.0
# Denmark                             0.592            22.0
# Norway                              0.603            16.0
# Iceland                             0.591             5.0
# Netherlands                         0.557           234.0

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
df_join.corr()
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.759468
# Social support                      0.759468        1.000000
# Healthy life expectancy             0.863062        0.765286
# Freedom to make life choices        0.394603        0.456246
# max_death_rate                      0.259893        0.204148
#
#                               Healthy life expectancy  \
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
# max_death_rate                               0.309666
#
#                               Freedom to make life choices  max_death_rate
# GDP per capita                                    0.394603        0.259893
# Social support                                    0.456246        0.204148
# ...

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
df_join.head()
# Out:
#              GDP per capita  Social support  Healthy life expectancy  \
# Finland               1.340           1.587                    0.986
# Denmark               1.383           1.573                    0.996
# Norway                1.488           1.582                    1.028
# Iceland               1.380           1.624                    1.026
# Netherlands           1.396           1.522                    0.999
#
#              Freedom to make life choices  max_death_rate
# Finland                             0.596            43.0
# Denmark                             0.592            22.0
# Norway                              0.603            16.0
# Iceland                             0.591             5.0
# Netherlands                         0.557           234.0

# %% [markdown]
# # Plotting GDP vs maximum Death rate

# %%
# %pip install seaborn
import seaborn as sns

x = df_join["GDP per capita"]
y = df_join["max_death_rate"]
sns.scatterplot(data=df_join, x="GDP per capita", y=np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_death_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# /lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_death_rate'>

# %% [markdown]
# ### Plotting Social support vs maximum Death rate

# %%
x = df_join["Social support"]
y = df_join["max_death_rate"]
sns.scatterplot(data=df_join, x="Social support", y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_death_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# /lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# <AxesSubplot:xlabel='Social support', ylabel='max_death_rate'>

# %% [markdown]
# ### Plotting Healthy life expectancy vs maximum Death rate

# %%
x = df_join["Healthy life expectancy"]
y = df_join["max_death_rate"]
sns.scatterplot(data=df_join, x="Healthy life expectancy", y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_death_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# /lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_death_rate'>

# %% [markdown]
# ### Plotting Freedom to make life choices vs maximum Death rate

# %%
x = df_join["Freedom to make life choices"]
y = df_join["max_death_rate"]
sns.scatterplot(data=df_join, x="Freedom to make life choices", y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_death_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# /lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1577: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_death_rate'>
